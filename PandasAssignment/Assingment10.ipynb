# %%
import pandas as pd
data = { 
    "Name" : ["Suraj","Shree","Krish","Saquib","Om","Mohit","Raj","Hitesh","Ram"],
    "Age" :[17,18,19,16,15,19,23,22,23],
    "City" :["Nashik","Pune","Mumbai","Dubai","Nashik","Deola","New York","Brazil","Africa"],
    "Marks":[90,20,45,79,89,23,45,67,99]}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age      City  Marks
# 0   Suraj   17    Nashik     90
# 1   Shree   18      Pune     20
# 2   Krish   19    Mumbai     45
# 3  Saquib   16     Dubai     79
# 4      Om   15    Nashik     89
# 5   Mohit   19     Deola     23
# 6     Raj   23  New York     45
# 7  Hitesh   22    Brazil     67
# 8     Ram   23    Africa     99

# %%
#created a csv file
df.to_csv("Assingment_1.csv",index= False)

# %%
#copied the data into a new dataframe
df1= pd.read_csv("Assingment_1.csv")
print(df1)
# Out:
#      Name  Age      City  Marks
# 0   Suraj   17    Nashik     90
# 1   Shree   18      Pune     20
# 2   Krish   19    Mumbai     45
# 3  Saquib   16     Dubai     79
# 4      Om   15    Nashik     89
# 5   Mohit   19     Deola     23
# 6     Raj   23  New York     45
# 7  Hitesh   22    Brazil     67
# 8     Ram   23    Africa     99

# %%
# What is Pandas?
#-Pandas is a Python library used for data analysis and manipulation.
# Why is Pandas used in AI/ML?
#-Pandas is used to load, clean, organize, and analyze data before training AI/ML models.
# What is a Series?
#A Series is a one-dimensional labeled array in Pandas.
# What is a DataFrame?
#A DataFrame is a two-dimensional table with rows and columns.
# What is a CSV file?
#A CSV (Comma-Separated Values) file stores tabular data in plain text, with values separated by commas.
# Write a program to create a DataFrame from a dictionary.
import pandas as pd
sample_data={
    "Name":["Suraj","Sahil","Soham"],
    "Age":[18,19,20],
    "Salary":[25000,22000,21000]}
dataframe = pd.DataFrame(sample_data)
